# %%
from pathlib import Path
path = Path(r'C:\Zeeshan\Vscode_projects\ML_pipeline/artifacts\data_transormation\train_data\Insurance_data.csv')
path
# Out:
# WindowsPath('C:/Zeeshan/Vscode_projects/ML_pipeline/artifacts/data_transormation/train_data/Insurance_data.csv')

# %%
import pandas as pd
df = pd.read_csv(path,index_col=[0])
df
# Out:
#            age       bmi  children  sex  smoker  region  expenses
# 0     0.472227 -1.757855  0.734336  0.0     0.0     1.0   9193.84
# 1     0.543313 -1.041339 -0.911192  0.0     0.0     0.0   8534.67
# 2     0.898745 -0.941360 -0.911192  0.0     0.0     2.0  27117.99
# 3    -0.025379  0.624978  3.202629  0.0     0.0     2.0   8596.83
# 4     1.040918 -1.507908  1.557100  0.0     0.0     1.0  12475.35
# ...        ...       ...       ...  ...     ...     ...       ...
# 1065 -1.518194  0.141746  2.379865  0.0     0.0     0.0   4561.19
# 1066 -0.025379 -1.107992  3.202629  0.0     0.0     2.0   8582.30
# 1067  1.325264 -0.891370 -0.911192  1.0     0.0     0.0  11931.13
# 1068 -0.167551  2.732868  0.734336  0.0     1.0     3.0  46113.51
# 1069  1.112004 -0.108202 -0.911192  1.0     0.0     3.0  10214.64
#
# [1070 rows x 7 columns]

# %%
X= df.iloc[:,:-1].values
y =df.iloc[:,-1]
y
# Out:
# 0        9193.84
# 1        8534.67
# 2       27117.99
# 3        8596.83
# 4       12475.35
#           ...
# 1065     4561.19
# 1066     8582.30
# 1067    11931.13
# 1068    46113.51
# 1069    10214.64
# Name: expenses, Length: 1070, dtype: float64

# %%
path1 = Path(r'C:\Zeeshan\Vscode_projects\ML_pipeline/artifacts\data_transormation\test_data\Insurance_data.csv')
df1=pd.read_csv(path1,index_col=[0])
X1= df1.iloc[:,:-1].values
y1=df1.iloc[:,-1]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
import numpy as np


# Define a dictionary of model names and their corresponding classes
models = {
    'Linear Regression': LinearRegression,
    'Decision Tree': DecisionTreeRegressor,
    'Random Forest': RandomForestRegressor,
    'MLP': MLPRegressor,
    'SVM': SVR,
    'Gradient Boosting': GradientBoostingRegressor,
    'K-Nearest Neighbors': KNeighborsRegressor
}

# Train and evaluate all models, and store their results in a dictionary
results = {}
for name, model_class in models.items():
    model = model_class().fit(X, y)
    y_pred = model.predict(X1)
    r2 = r2_score(y1, y_pred)
    n = X1.shape[0]
    p = X1.shape[1]
    adj_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))
    mae = mean_absolute_error(y1, y_pred)
    mse = mean_squared_error(y1, y_pred)
    rmse = np.sqrt(mse)
    results[name] = {'model': model, 'R-squared': r2, 'Adjusted R-squared': adj_r2, 'MAE': mae, 'MSE': mse, 'RMSE': rmse}
    print(results)

# # Find the best model based on your chosen evaluation metric
# best_model_name = max(results,key=lambda x: results[x]['R-squared'])

# # Use the best model for prediction
# best_model = results[best_model_name]['model']
# y_pred = best_model.predict(X1)
# Out:
# {'Linear Regression': {'model': LinearRegression(), 'R-squared': 0.7825694308433617, 'Adjusted R-squared': 0.7775710269547034, 'MAE': 4190.512674325151, 'MSE': 33755820.53511167, 'RMSE': 5809.975949615598}}
# {'Linear Regression': {'model': LinearRegression(), 'R-squared': 0.7825694308433617, 'Adjusted R-squared': 0.7775710269547034, 'MAE': 4190.512674325151, 'MSE': 33755820.53511167, 'RMSE': 5809.975949615598}, 'Decision Tree': {'model': DecisionTreeRegressor(), 'R-squared': 0.7847401259994499, 'Adjusted R-squared': 0.7797916231488625, 'MAE': 2639.3120149253737, 'MSE': 33418822.86082164, 'RMSE': 5780.90156124645}}
# ...

# %%
results['Linear Regression']['model'].predict(X1)
# Out:
# array([ 9.06304426e+03,  7.14397938e+03,  3.70210479e+04,  9.64421532e+03,
#         2.69937290e+04,  1.07368076e+04,  2.84642947e+02,  1.69712709e+04,
#         1.18540635e+03,  1.14038742e+04,  2.81693708e+04,  9.51091509e+03,
#         5.37030438e+03,  3.84828928e+04,  4.02861555e+04,  3.71516766e+04,
#         1.52846561e+04,  3.59663153e+04,  9.28136974e+03,  3.15827349e+04,
#         3.95650864e+03,  1.01370144e+04,  2.31384378e+03,  7.00228032e+03,
#         1.14780094e+04,  1.29633752e+04,  1.44828745e+04,  6.27520889e+03,
#         1.00395988e+04,  2.23010412e+03,  9.17806632e+03,  1.31719466e+04,
#         4.59113656e+03,  3.64521973e+03,  4.43921412e+03,  1.29468086e+04,
#         1.97678860e+03,  8.82061877e+03,  3.34398342e+04,  3.26473359e+04,
#         3.95407693e+03,  4.40897158e+03,  1.41199490e+04,  1.16143721e+04,
#         8.86911898e+03,  1.21661704e+04,  5.32604572e+03,  3.21199504e+03,
# ...

# %%
a=results[best_model_name].values()

# %%
b=results[best_model_name].keys()

# %%
for i , j in zip(a,b):
    print(f'{j,i}')
# Out:
# ('model', GradientBoostingRegressor())
# ('R-squared', 0.8776384507640782)
# ('Adjusted R-squared', 0.8748255415862409)
# ('MAE', 2589.03552446653)
# ('MSE', 18996475.57575234)
# ('RMSE', 4358.494645603266)

# %%
pd.DataFrame(results)
# Out:
#                      Linear Regression            Decision Tree  \
# model               LinearRegression()  DecisionTreeRegressor()
# R-squared                     0.782569                 0.745387
# Adjusted R-squared            0.777571                 0.739534
# MAE                        4190.512674              2885.256418
# MSE                    33755820.535112          39528351.041707
# RMSE                        5809.97595              6287.157628
#
#                                                         Random Forest  \
# model               (DecisionTreeRegressor(max_features=1.0, rando...
# R-squared                                                    0.866292
# Adjusted R-squared                                           0.863219
# MAE                                                       2624.070112
# MSE                                                   20757951.748917
# RMSE                                                      4556.089524
#
# ...
